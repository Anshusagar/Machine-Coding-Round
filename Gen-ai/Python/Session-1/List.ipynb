# %%
friuts = ['apple']
print(frouits)
# Out:
# Failed to start the Kernel.
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#
#   - package pyzmq-22.3.0-py310h5cfa1c3_2 requires python >=3.10,<3.11.0a0 *_cpython, but none of the providers can be installed
#
#
#
# Could not solve for environment specs
#
# The following packages are incompatible
#
# ├─ pin on python =3.13 * is installable and it requires
#
# │  └─ python =3.13 *, which can be installed;
#
# └─ pyzmq <25 * is not installable because there are no viable options
#
#    ├─ pyzmq [20.0.0|21.0.0|...|24.0.1] would require
#
#    │  └─ python >=3.8,<3.9.0a0 *, which conflicts with any installable versions previously reported;
#
#    ├─ pyzmq [20.0.0|21.0.0|...|24.0.1] would require
#
#    │  └─ python >=3.9,<3.10.0a0 *, which conflicts with any installable versions previously reported;
#
#    ├─ pyzmq [22.3.0|23.0.0|...|24.0.1] would require
#
# ...
